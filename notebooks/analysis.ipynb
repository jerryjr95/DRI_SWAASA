# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: c:\Users\user\OneDrive\Desktop\portfolio\portfolio_projects\DRI_SWAASA

# %%
from src.paths import RAW_AUDIO_DIR, PROCESSED_AUDIO_DIR, PLOTS_DIR

# %%
print(RAW_AUDIO_DIR)
print(PROCESSED_AUDIO_DIR)
print(PLOTS_DIR)
# Out:
# c:\Users\user\OneDrive\Desktop\portfolio\portfolio_projects\DRI_SWAASA\data\raw\audio
# c:\Users\user\OneDrive\Desktop\portfolio\portfolio_projects\DRI_SWAASA\data\processed\audio
# c:\Users\user\OneDrive\Desktop\portfolio\portfolio_projects\DRI_SWAASA\plots
